# %%
print("Hello World")
# Out:
# Hello World

# %%
print(3)
# Out:
# 3

# %%
print(-10)
# Out:
# -10

# %%
print((11**12)%13)
# Out:
# 1

# %%
print(1<10)
# Out:
# True

# %%
print(2**3)
# Out:
# 8

# %%
print(5%3)
# Out:
# 2

# %%
print((11**13)%4)
# Out:
# 3

# %%
print(10//3)
# Out:
# 3

# %%
print(10==3)
# Out:
# False

# %%
num = 2
print(num)
# Out:
# 2

# %%
number = 2
print(number)
number = 2
# Out:
# 2

# %%
number = 2
print(number < 3)
# Out:
# True

# %%
number = 2
print(number> 10)
# Out:
# False

# %%
number += 2
print(number)
# Out:
# 4

# %%
num *= 2
print(num)
# Out:
# 4

# %%
number /= 2
print(number)
# Out:
# 2.0

# %%
num = 10
num1 = 13*2
print(num*num1)
# Out:
# 260

# %%
print(abs(-5)) # 절댓값
# Out:
# 5

# %%
print(pow(3,3)) # 제곱
# Out:
# 27

# %%
print(max(5,12))
# Out:
# 12

# %%
list1=[1,3,5,7,9,11,13,15] # list는 하나의 정의된 이름 요구
print(min(list1))
# Out:
# 1

# %%
print(round(3.14)) # round 반올림
# Out:
# 3

# %%
from math import *
print(floor(4.99)) # 내림 4
print(ceil(3.3)) # 올림 4
# Out:
# 4
# 4

# %%
from random import *
print(random())
# Out:
# 0.4122194795919446

# %%
from random import *
print(random())
print(random() * 10)
# Out:
# 0.3792416549556241
# 5.985132196878938

# %%
from random import *
print(int(random() * 10))
# Out:
# 1

# %% [markdown]
# ## 이 제목은 2단계

# %% [markdown]
# ## 한국공대

# %% [markdown]
# ## 배고파

# %% [markdown]
# ### 부제목

# %%
import pylab as py

x_deg = py.arange(-180, 180+1)
x_rad = py.deg2rad(x_deg)
y = py.sin(x_rad)

py.plot(x_deg, y)

py.xlabel('x(deg)')
py.ylabel('sin(x)')
py.grid(True)
